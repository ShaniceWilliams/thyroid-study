# %% [markdown]
# # Feature Selection
#
# According to Welch Dinauer et al (1998), in younger patients risk of recurrence is most strongly related to tumour size and if there were already metastasis at diagnosis. When considering the data that we have in this data set, we will need to look to [insert column names here] to see if this trend can also be seen in older patients.

# %% [markdown]
# ## Univariate Selection

# %% [markdown]
# ## Recursive Feature Elimination

# %% [markdown]
# ## Feature Importance

# %% [markdown]
# ### References
#
# - Welch Dinauer, C.A., Michael Tuttle, , Robie, D.K., McClellan, D.R., Svec, R.L., Adair, C. and Francis, G.L. (1998), Clinical features associated with metastasis and recurrence of differentiated thyroid cancer in children, adolescents and young adults. Clinical Endocrinology, 49: 619-628. https://doi.org/10.1046/j.1365-2265.1998.00584.x
